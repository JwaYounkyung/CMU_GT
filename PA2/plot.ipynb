# %%
import matplotlib.pyplot as plt
import pickle

# %%
with open('results/maddpg_simple/test_agrewards2.pkl', 'rb') as f:
    data = pickle.load(f)

print(data)

def result_plot(data):
    plt.clf() 
    plt.figure(figsize=(15, 5))

    epochs = range(1000, len(data)*1000 + 1,1000)

    plt.plot(epochs, data, label='Average Reward', marker='o')
    plt.title('Average Reward on the Simple Scenario')
    plt.legend()

    plt.show()

result_plot(data)
# Out:
# [-35.74620630954958, -17.523373569986877, -6.739478262480365, -6.743257456664758, -6.026529813763671]

# %%
with open('results/maddpg_uav/test_agrewards2.pkl', 'rb') as f:
    data = pickle.load(f)

agent1, agent2, agent3 = [], [], []
for i in range(0, int(len(data)/3)):
    agent1.append(data[3*i])
    agent2.append(data[3*i+1])
    agent3.append(data[3*i+2])
print(agent1, agent2, agent3)
print(data)

def result_plot(data):
    plt.clf() 
    plt.figure(figsize=(15, 5))

    epochs = range(500, len(agent1)*500 + 1,500)

    plt.plot(epochs, agent1, label='poacher', marker='o')
    plt.plot(epochs, agent2, label='ranger', marker='o')
    plt.plot(epochs, agent3, label='UAV', marker='o')
    plt.title('Average Reward on the Ranger-Poacher Scenario')
    plt.legend()

    plt.show()

result_plot(data)
# Out:
# [-0.06, -0.054, -0.048, -0.056, -0.054, -0.056] [0.06, 0.054, 0.048, 0.056, 0.054, 0.056] [0.06, 0.054, 0.048, 0.056, 0.054, 0.056]
# [-0.06, 0.06, 0.06, -0.054, 0.054, 0.054, -0.048, 0.048, 0.048, -0.056, 0.056, 0.056, -0.054, 0.054, 0.054, -0.056, 0.056, 0.056]

# %%
with open('results/maddpg_shaping/test_agrewards.pkl', 'rb') as f:
    data = pickle.load(f)

agent1, agent2, agent3 = [], [], []
for i in range(0, int(len(data)/3)):
    agent1.append(data[3*i])
    agent2.append(data[3*i+1])
    agent3.append(data[3*i+2])
print(agent1, agent2, agent3)
print(data)

def result_plot(data):
    plt.clf() 
    plt.figure(figsize=(15, 5))

    epochs = range(500, len(agent1)*500 + 1,500)

    plt.plot(epochs, agent1, label='poacher', marker='o')
    plt.plot(epochs, agent2, label='ranger', marker='o')
    plt.plot(epochs, agent3, label='UAV', marker='o')
    plt.title('Average Reward on the Ranger-Poacher Scenario')
    plt.legend()

    plt.show()

result_plot(data)
# Out:
# [1.1049229581796798, 0.8907284990208431, 1.0490947872496699, 1.470980479033491, 1.529249075029617, 1.71698267214319] [0.977, 1.146, 0.773, 0.687, 1.125, 0.097] [0.977, 1.146, 0.773, 0.687, 1.125, 0.097]
# [1.1049229581796798, 0.977, 0.977, 0.8907284990208431, 1.146, 1.146, 1.0490947872496699, 0.773, 0.773, 1.470980479033491, 0.687, 0.687, 1.529249075029617, 1.125, 1.125, 1.71698267214319, 0.097, 0.097]

# %%
with open('results/maddpg_shaping/test_agrewards.pkl', 'rb') as f:
    data = pickle.load(f)

agent1, agent2, agent3 = [], [], []
for i in range(0, int(len(data)/3)):
    agent1.append(data[3*i])
    agent2.append(data[3*i+1])
    agent3.append(data[3*i+2])
print(agent1, agent2, agent3)
print(data)

def result_plot(data):
    plt.clf() 
    plt.figure(figsize=(15, 5))

    epochs = range(500, len(agent1)*500 + 1,500)

    plt.plot(epochs, agent1, label='poacher', marker='o')
    plt.plot(epochs, agent2, label='ranger', marker='o')
    plt.plot(epochs, agent3, label='UAV', marker='o')
    plt.title('Average Reward on the Ranger-Poacher Scenario')
    plt.legend()

    plt.show()

result_plot(data)
# Out:
# [1.9896729371481172, 1.994122422855407, 1.6954722497645658, 2.707396809897065, 3.0770349812775613, 3.783916470057441] [0.907, 0.692, 0.618, 0.685, 1.083, 2.41] [0.907, 0.692, 0.618, 0.685, 1.083, 2.41]
# [1.9896729371481172, 0.907, 0.907, 1.994122422855407, 0.692, 0.692, 1.6954722497645658, 0.618, 0.618, 2.707396809897065, 0.685, 0.685, 3.0770349812775613, 1.083, 1.083, 3.783916470057441, 2.41, 2.41]
